# %%
import pandas as pd
df=pd.read_csv('spike1.csv',skiprows=7)

# %%
df
# Out:
#        Well Treatment  Conc(M)  TOI(min)  Channel in well  Channel  Selected  \
# 0        A1      none      NaN         0                1        1         0
# 1        A1      none      NaN         0                1        1         0
# 2        A1      none      NaN         0                1        1         0
# 3        A1      none      NaN         0                1        1         0
# 4        A1      none      NaN         0                2        2         0
# ...     ...       ...      ...       ...              ...      ...       ...
# 251317   H3      test      3.0         5                2      306         0
# 251318   H3      test      3.0         5                2      306         0
# 251319   H3      test      3.0         5                4      308         0
# 251320   H3      test      3.0         5                4      308         0
# 251321   H3      test      3.0         5                5      313         0
#
# ...

# %%
df_well=df[df.Well=='A1']

# %%
df_well
# Out:
#        Well Treatment  Conc(M)  TOI(min)  Channel in well  Channel  Selected  \
# 0        A1      none      NaN         0                1        1         0
# 1        A1      none      NaN         0                1        1         0
# 2        A1      none      NaN         0                1        1         0
# 3        A1      none      NaN         0                1        1         0
# 4        A1      none      NaN         0                2        2         0
# ...     ...       ...      ...       ...              ...      ...       ...
# 251223   A1      none      NaN         0                2        2         0
# 251224   A1      none      NaN         0                3        3         0
# 251225   A1      none      NaN         0                3        3         0
# 251226   A1      none      NaN         0                4        4         1
# 251229   A1      none      NaN         0                6       10         1
#
# ...

# %%
df_well=df_well.sort_values(by=['Within_session_time'])
df_well.to_csv("a1.csv")

# %%
y=df_well['Channel in well'].tolist()

# %%
output = []
for x in y:
    if x not in output:
        output.append(x)
print(output)
# Out:
# [1, 2, 3, 4, 7, 8, 5, 6]
